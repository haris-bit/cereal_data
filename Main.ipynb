# %%
import pandas as pd
df = pd.read_excel("cereal_data.xls", "cereal")
df
# Out:
#                     name mfr type  calories  protein  fat  sodium  fiber  \
# 0              Corn Chex   R    C     110.0      2.0  0.0   280.0    0.0
# 1            Corn Flakes   K    C     100.0      2.0  0.0   290.0    1.0
# 2          Rice Krispies   K    C     110.0      2.0  0.0   290.0    0.0
# 3              Special K   K  NaN     110.0      6.0  0.0   230.0    1.0
# 4   Multi-Grain Cheerios   G    C     100.0      2.0  1.0   220.0    2.0
# ..                   ...  ..  ...       ...      ...  ...     ...    ...
# 72     Grape Nuts Flakes   P    C     100.0      3.0  1.0   140.0    3.0
# 73             Rice Chex   R    C       NaN      1.0  0.0   240.0    0.0
# 74              Cheerios   G    C     110.0      6.0  2.0   290.0    2.0
# 75            Honey-comb   P    C     110.0      1.0  0.0   180.0    0.0
# 76                   Kix   G    C     110.0      2.0  1.0   260.0    0.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
df.shape
# Out:
# (77, 16)

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  75.000000   76.000000  75.000000  75.000000
# mean   106.842105   2.539474   1.013333  159.671053   2.156000  14.600000
# std     19.610237   1.100797   1.019981   84.389318   2.415224   4.335585
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  128.750000   0.500000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.500000  14.000000
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  75.000000   76.000000   76.000000  76.000000  74.000000  76.000000
# mean    6.933333   96.092105   28.289474   2.210526   1.030811   0.821316
# std     4.503252   71.760375   22.487813   0.837708   0.153416   0.234250
# ...

# %%
df.isnull().sum()
# Out:
# name        0
# mfr         4
# type        6
# calories    1
# protein     1
# fat         2
# sodium      1
# fiber       2
# carbo       2
# sugars      2
# potass      1
# vitamins    1
# shelf       1
# weight      3
# cups        1
# rating      0
# dtype: int64

# %%
dropped_table = df.fillna(0)
dropped_table
# Out:
#                     name mfr type  calories  protein  fat  sodium  fiber  \
# 0              Corn Chex   R    C     110.0      2.0  0.0   280.0    0.0
# 1            Corn Flakes   K    C     100.0      2.0  0.0   290.0    1.0
# 2          Rice Krispies   K    C     110.0      2.0  0.0   290.0    0.0
# 3              Special K   K    0     110.0      6.0  0.0   230.0    1.0
# 4   Multi-Grain Cheerios   G    C     100.0      2.0  1.0   220.0    2.0
# ..                   ...  ..  ...       ...      ...  ...     ...    ...
# 72     Grape Nuts Flakes   P    C     100.0      3.0  1.0   140.0    3.0
# 73             Rice Chex   R    C       0.0      1.0  0.0   240.0    0.0
# 74              Cheerios   G    C     110.0      6.0  2.0   290.0    2.0
# 75            Honey-comb   P    C     110.0      1.0  0.0   180.0    0.0
# 76                   Kix   G    C     110.0      2.0  1.0   260.0    0.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
df
# Out:
#                     name mfr type  calories  protein  fat  sodium  fiber  \
# 0              Corn Chex   R    C     110.0      2.0  0.0   280.0    0.0
# 1            Corn Flakes   K    C     100.0      2.0  0.0   290.0    1.0
# 2          Rice Krispies   K    C     110.0      2.0  0.0   290.0    0.0
# 3              Special K   K  NaN     110.0      6.0  0.0   230.0    1.0
# 4   Multi-Grain Cheerios   G    C     100.0      2.0  1.0   220.0    2.0
# ..                   ...  ..  ...       ...      ...  ...     ...    ...
# 72     Grape Nuts Flakes   P    C     100.0      3.0  1.0   140.0    3.0
# 73             Rice Chex   R    C       NaN      1.0  0.0   240.0    0.0
# 74              Cheerios   G    C     110.0      6.0  2.0   290.0    2.0
# 75            Honey-comb   P    C     110.0      1.0  0.0   180.0    0.0
# 76                   Kix   G    C     110.0      2.0  1.0   260.0    0.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
df.isnull().sum()
# Out:
# name        0
# mfr         4
# type        6
# calories    1
# protein     1
# fat         2
# sodium      1
# fiber       2
# carbo       2
# sugars      2
# potass      1
# vitamins    1
# shelf       1
# weight      3
# cups        1
# rating      0
# dtype: int64

# %%
dropped_table.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
df["weight"].mean()
# Out:
# 1.0308108108108107

# %%
copied_df = df

# %%
copied_df.fillna({
    "weight": copied_df["weight"].mean()
})
# Out:
#                     name mfr type  calories  protein  fat  sodium  fiber  \
# 0              Corn Chex   R    C     110.0      2.0  0.0   280.0    0.0
# 1            Corn Flakes   K    C     100.0      2.0  0.0   290.0    1.0
# 2          Rice Krispies   K    C     110.0      2.0  0.0   290.0    0.0
# 3              Special K   K  NaN     110.0      6.0  0.0   230.0    1.0
# 4   Multi-Grain Cheerios   G    C     100.0      2.0  1.0   220.0    2.0
# ..                   ...  ..  ...       ...      ...  ...     ...    ...
# 72     Grape Nuts Flakes   P    C     100.0      3.0  1.0   140.0    3.0
# 73             Rice Chex   R    C       NaN      1.0  0.0   240.0    0.0
# 74              Cheerios   G    C     110.0      6.0  2.0   290.0    2.0
# 75            Honey-comb   P    C     110.0      1.0  0.0   180.0    0.0
# 76                   Kix   G    C     110.0      2.0  1.0   260.0    0.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
copied_df.isnull().sum()
# Out:
# name        0
# mfr         4
# type        6
# calories    1
# protein     1
# fat         2
# sodium      1
# fiber       2
# carbo       2
# sugars      2
# potass      1
# vitamins    1
# shelf       1
# weight      3
# cups        1
# rating      0
# dtype: int64

# %%
newOne = df.fillna({
    "weight": df["weight"].mean()
})

# %%
df.isnull().sum()
# Out:
# name        0
# mfr         4
# type        6
# calories    1
# protein     1
# fat         2
# sodium      1
# fiber       2
# carbo       2
# sugars      2
# potass      1
# vitamins    1
# shelf       1
# weight      3
# cups        1
# rating      0
# dtype: int64

# %%
newOne.isnull().sum()
# Out:
# name        0
# mfr         4
# type        6
# calories    1
# protein     1
# fat         2
# sodium      1
# fiber       2
# carbo       2
# sugars      2
# potass      1
# vitamins    1
# shelf       1
# weight      0
# cups        1
# rating      0
# dtype: int64

# %%
result = df.head(10)
result
# Out:
#                      name mfr type  calories  protein  fat  sodium  fiber  \
# 0               Corn Chex   R    C     110.0      2.0  0.0   280.0    0.0
# 1             Corn Flakes   K    C     100.0      2.0  0.0   290.0    1.0
# 2           Rice Krispies   K    C     110.0      2.0  0.0   290.0    0.0
# 3               Special K   K  NaN     110.0      6.0  0.0   230.0    1.0
# 4    Multi-Grain Cheerios   G    C     100.0      2.0  1.0   220.0    2.0
# 5                Wheaties   G    C     100.0      3.0  1.0   200.0    3.0
# 6  Cream of Wheat (Quick)   N    H     100.0      3.0  0.0    80.0    1.0
# 7               Corn Pops   K    C     110.0      1.0  0.0    90.0    1.0
# 8                    Trix   G    C     110.0      1.0  1.0   140.0    0.0
# 9             Froot Loops   K    C     110.0      2.0  1.0   125.0    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0   22.0     3.0    25.0      25.0    1.0     1.0   1.0  41.445019
# ...

# %%
result = df.tail(10)
result
# Out:
#                       name  mfr type  calories  protein  fat  sodium  fiber  \
# 67  Just Right Fruit & Nut  NaN    C     140.0      3.0  1.0   170.0    2.0
# 68             Raisin Bran  NaN    C     120.0      3.0  1.0   210.0    5.0
# 69                 Basic 4    G    C     130.0      3.0  2.0   210.0    2.0
# 70     Frosted Mini-Wheats  NaN    C     100.0      NaN  0.0     0.0    3.0
# 71            Golden Crisp    P    C     100.0      2.0  0.0    45.0    0.0
# 72       Grape Nuts Flakes    P    C     100.0      3.0  1.0   140.0    3.0
# 73               Rice Chex    R    C       NaN      1.0  0.0   240.0    0.0
# 74                Cheerios    G    C     110.0      6.0  2.0   290.0    2.0
# 75              Honey-comb    P    C     110.0      1.0  0.0   180.0    0.0
# 76                     Kix    G    C     110.0      2.0  1.0   260.0    0.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...
